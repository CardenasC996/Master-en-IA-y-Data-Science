# %% [markdown]
# Recordar que el Markdown es para mensajes que no afectan el codigo

# %%
print("Hola, mundo es mi primer programa")
# Out:
# Hola, mundo es mi primer programa

# %%
Y= 12 
X= 22
print(X+Y)
# Out:
# 34

# %%
Mediana= (X+Y)/2
print(Mediana)
# Out:
# 17.0

# %%
x = 1 # esto es un integer
y = 1.5 # esto es un float 
z = "Hola, mundo" # esto es un string
w = True # esto es un booleano 
print(x)
print(y)
print(z)
print(w)    
print(type(x))
print(type(y))
print(type(z))
print(type(w))
# Out:
# 1
# 1.5
# Hola, mundo
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
X= 2147483648 # esto es un integer grande cosa que en Java no se puede hacer, python es dinamico y no tiene un limite para los enteros
print(X)
# Out:
# 2147483648
